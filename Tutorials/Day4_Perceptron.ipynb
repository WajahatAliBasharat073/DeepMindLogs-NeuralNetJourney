# %% [markdown]
# ### Perceptron

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../Tutorials/placement_dataset.csv")
df.head()
# Out:
#    cgpa  resume_score  placement
# 0  0.64          8.77          0
# 1  8.95          4.89          0
# 2  7.72          6.78          1
# 3  6.63          0.37          1
# 4  2.59          2.85          0

# %%
df.shape
# Out:
# (100, 3)

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'],
                hue=df['placement'], palette='coolwarm')

# Labels and title
plt.xlabel("CGPA")
plt.ylabel("Resume Score")
plt.title("Scatter Plot of CGPA vs Resume Score with Placement Hue")

# Show plot
plt.show()

# %%
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()

# %%
p.fit(X,Y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 1.74, -4.8 ]])

# %%
p.intercept_
# Out:
# array([12.])

# %%
# %pip install mlextend
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement mlextend (from versions: none)
# ERROR: No matching distribution found for mlextend

# %%
from mlextend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from mlextend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlextend'
